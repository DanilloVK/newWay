# %%
# Fetch the MNIST db from tensorflow

# %% [markdown]
# # Cell 2 Rapportage
# Opdracht door middel van een gedeelde github uitgevoerd door:<br>
# Joost Both<br>
# 1063674<br></br>
# Danillo van Kesteren<br>
# 1045405<br>

# %%
# Cell 3 Dataset-verkenning


# Hoeveel afbeeldingen bevat MNIST:



# Hoeveel voorbeelden zijn er per cijfer (0-9):



# Is de dataset gebalanceerd



# Welk cijfer komt het meest voor:



# Welk cijfer komt het minst voor:



# Hoe groot is één afbeelding (vorm en datatype):
