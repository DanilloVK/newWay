# %%
# Fetch the MNIST db from tensorflow

# %% [markdown]
# <!-- Cell 2 Rapportage -->
# Opdracht door middel van een gedeelde github uitgevoerd door:
# Joost Both
# 1063674
#
# Danillo van Kesteren
# 1045405
